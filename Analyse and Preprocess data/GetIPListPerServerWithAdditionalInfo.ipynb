# %%
instance_no = '05'

# %%
# !gsutil cp gs://store_data_gh/results_scan_on_port_80/round_7/zipped/zgrab_result_instance-05_7_443_20210903.json.bz2 $HOME/myprojectdir/Data/data.json.bz2
# Out:
# Copying gs://store_data_gh/results_scan_on_port_80/round_7/zipped/zgrab_result_instance-05_7_443_20210903.json.bz2...
# ==> NOTE: You are downloading one or more large file(s), which would
# run significantly faster if you enabled sliced object downloads. This
# feature is enabled by default but requires that compiled crcmod be
# installed (see "gsutil help crcmod").
#
# | [1 files][780.1 MiB/780.1 MiB]
# Operation completed over 1 objects/780.1 MiB.

# %%
# !bzip2 -d $HOME/myprojectdir/Data/data.json.bz2

# %%
# !cat $HOME/myprojectdir/Data/data.json | jsoncsv | mkexcel > $HOME/myprojectdir/Data/data.csv

# %%
# !rm $HOME/myprojectdir/Data/data.json

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
batch_no=1

for chunk in pd.read_csv('Data/data.csv',chunksize=100000):
  chunk.to_csv('Data/100KChunks/Banner'+str(batch_no)+'.csv',index=False)
  batch_no+=1
    
no_of_chunks = batch_no-1
# Out:
# /home/shnrndk3/myprojectdir/myprojectenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (6,8,9,10,11,14,15,20,21,26,28,29,32,33,65,67,68,71,72,73,79,80,82,84,87,88,89,90,91,92,93,97,98,99,100,101,102,103,104,105,106,107,111,112,113,114,118,119,123,124,126,127,144,145,146,153,154,155,156,157,159,160,161,162,163,164,165,166,167,168,169,170,171,174,176,177,179,180,191,202,205,206,211,212,213,224,235,238,239,244,245,246,248,250,251,252,295,299,300,301,304,305,306,307,317,328,339,341,342,343,344,345,348,349,355,356,361,362,363,364,366,367,368,369,370,381,427,429,434,437,438,443,444,453,454,455,456,459,460,462,464,467,977,978,979,980,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1018,1019,1020,1021,1022,1023,1024,1025,1040,1047,1055,1056,1057,1058,1062,1063,1065,1066,1067,1068,1069,1070,1071,1072,1073,1074,1075,1076,1077,1078,1079,1083,1084,1085,1108,1109
# ...

# %%
no_of_chunks = 28
instance_no = '01'
round_no = '3'

# %%
c = pd.read_csv('Data/100KChunks/Banner1.csv')
# Out:
# /home/shnrndk3/myprojectdir/myprojectenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (9,10,11,18,19,22,23,24,25,26,30,31,33,35,36,48,50,51,52,53,54,61,62,63,64,67,70,72,73,74,75,76,77,78,79,80,83,94,105,108,109,110,111,112,113,115,116,121,123,124,125,141,142,143,144,145,146,147,150,151,152,153,154,156,157,158,159,160,161,162,163,164,166,167,168,172,174,176,178,179,181,183,184,186,187,190,192,194,195,208,213,214,215,218,219,220,230,231,235,238,239,240,241,247,248,249,250,252,253,255,257,290,293,298,299,300,301,302,303,305,306,307,308,309,310,318,336,338,339,343,344,347,350,353,364,375,386,397,408,419,430,441,452,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,489,500,511,522,533,544,546,547,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1559,1560,1561,1567,1568,1569,1571,1572,1592,1620,1621,1648,1649,1650,1672,1673,1674,1695,1696,1706,1707,1708,1709,1710,1712,1713,1715,1718,1719,17
# ...

# %%
c.columns
# Out:
# Index(['data.http.error', 'data.http.protocol', 'data.http.result',
#        'data.http.result.redirect_response_chain.0.body',
#        'data.http.result.redirect_response_chain.0.body_sha256',
#        'data.http.result.redirect_response_chain.0.content_length',
#        'data.http.result.redirect_response_chain.0.headers.accept.0',
#        'data.http.result.redirect_response_chain.0.headers.accept_encoding.0',
#        'data.http.result.redirect_response_chain.0.headers.accept_language.0',
#        'data.http.result.redirect_response_chain.0.headers.accept_ranges.0',
#        ...
#        'data.http.result.response.request.url.host',
#        'data.http.result.response.request.url.path',
#        'data.http.result.response.request.url.scheme',
#        'data.http.result.response.status_code',
#        'data.http.result.response.status_line',
#        'data.http.result.response.trailers.unknown.0.key',
#        'data.http.result.response.transfer_encoding.0', 'data.http.status',
# ...

# %%
c.iloc[:,209:]
# Out:
# 0         <HTML><HEAD>\n<TITLE>Invalid URL</TITLE>\n</HE...
# 1         <!DOCTYPE html>\n<html lang=en>\n  <meta chars...
# 2         <HTML><HEAD>\n<TITLE>Invalid URL</TITLE>\n</HE...
# 3                                                       NaN
# 4         <HTML><HEAD>\n<TITLE>Invalid URL</TITLE>\n</HE...
#                                 ...
# 99997     <html>\r\n<head><title>403 Forbidden</title></...
# 99998     <HTML><HEAD>\n<TITLE>Invalid URL</TITLE>\n</HE...
# 99999     <HTML><HEAD>\n<TITLE>Invalid URL</TITLE>\n</HE...
# 100000    <HTML><HEAD>\n<TITLE>Invalid URL</TITLE>\n</HE...
# 100001    <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//...
# Name: data.http.result.response.body, Length: 100002, dtype: object

# %%
columnnames = []

for i in range(no_of_chunks):
    print(i)
    c = pd.read_csv('Data/100KChunks/Banner'+str(i+1)+'.csv')
    c = c.dropna(subset=['data.http.result.response.headers.server.0'],axis = 0)
    c.iloc[:,209:]
    columnnames = c.columns.values
    c.to_csv('Data/100KChunks/TempIPlistPerServerAddInfo'+str(i+1)+'.csv',index=False)
# Out:
# 0
# ...

# %%
for i in range(no_of_chunks):
    c = pd.read_csv('Data/100KChunks/TempIPlistPerServerAddInfo'+str(i+1)+'.csv')
    c.to_csv('Data/100KChunks/TempIPlistPerServerAddInfo.csv', mode='a', header=False,index=False)
# Out:
# /home/shnrndk3/myprojectdir/myprojectenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (4,5,8,10,17,18,22,23,24,28,29,30,34,35,37,40,42,45,47,52,63,65,66,67,68,69,70,75,78,81,84,86,89,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,146,157,159,160,161,163,164,167,168,169,176,187,188,189,190,191,192,209,236,254,255,256,262,263,264,277,278,280,281,283,284,286,287,293,294,301,303,304,306,313,321,323,345,356,363) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
df = pd.read_csv('Data/100KChunks/TempIPlistPerServerAddInfo.csv',names = columnnames)

# %%
df = df.sort_values(by=[ 'data.http.result.response.headers.server.0'])

# %%
df

# %%
df.to_csv('Data/100KChunks/FinalIPlistPerServer_additional_info_Instance_no_'+instance_no+'_round_'+round_no+'.csv',index=False)

# %%
# !pwd
# Out:
# /home/shnrndk3/myprojectdir

# %%
# !bzip2 /home/shnrndk3/myprojectdir/Data/100KChunks/FinalIPlistPerServer_additional_info_Instance_no_06_round_2.csv

# %%
c = pd.read_csv('Data/data.csv')

# %%
c = c.dropna(subset=['data.http.result.response.headers.server.0'],axis = 0)
c = c.iloc[:,512:1421]

# %%
c = c.sort_values(by=[ 'data.http.result.response.headers.server.0'])

# %%
c.to_csv('Data/FinalIPlistPerServer_additional_info_Instance_no_'+instance_no+'_round_'+round_no+'.csv',index=False)
